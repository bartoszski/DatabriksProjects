# %%
nb_path = dbutils.entry_point.getDbutils().notebook().getContext().notebookPath().get()
nb_name = nb_path.split("/")[-1]

print(f"Notebook path: {nb_path}")
print(f"Notebook name: {nb_name}")
dbutils.widgets.removeAll()   
dbutils.widgets.text("nb_path", nb_path)

# %sql
SELECT "$nb_path" nb_path
